# %%
# %matplotlib inline

# %%
import pickle

# %%
import pandas as pd
import torch
from torch import nn

# %%
import matplotlib.pyplot as plt

# %%
import sys

# %%
sys.path.append('../../')

# %%
from omd2l.data.KaggleHouse import KaggleHouse

# %%
from omd2l.models.base.Trainer import Trainer

# %%
from omd2l.models.linear.LinearRegressionScratch import LinearRegressionScratch
from omd2l.models.linear.LinearRegression import LinearRegression

# %%
from omd2l.models.MLP.MLPScratch import MLPScratch
from omd2l.models.MLP.MLP import MLP
 
from omd2l.models.MLP.DropoutMLPScratch import DropoutMLPScratch
from omd2l.models.MLP.DropoutMLPRegressor import DropoutMLPRegressor

# %%
data = KaggleHouse(batch_size=64)
print(data.raw_train.shape)
print(data.raw_val.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
print(data.raw_train.iloc[:4, [0, 1, 2, 3, -3, -2, -1]])
# Out:
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000

# %%
data.preprocess()
data.train.shape
# Out:
# (1460, 332)

# %%
def k_fold_data(data, k):
    rets = []
    fold_size = data.train.shape[0] // k
    for j in range(k):
        idx = range(j * fold_size, (j+1) * fold_size)
        rets.append(KaggleHouse(batch_size=data.batch_size, 
                                train=data.train.drop(index=idx),
                                val=data.train.loc[idx]))
    return rets

# %%
def k_fold(trainer, data, k, model ):
    val_loss, models = [], []
    for i, data_fold in enumerate(k_fold_data(data, k)):
        model.board.yscale='log'
        if i != 0: model.board.display = False
        trainer.fit(model, data_fold)
        val_loss.append(float(model.board.data['val_loss'][-1].y))
        models.append(model)
    avg_val_log_loss = sum(val_loss)/len(val_loss)
    return models, avg_val_log_loss

# %%
lr_hparams = {'lr':0.01}
lr_model = LinearRegression(**lr_hparams)
# Out:
# /Users/oualid/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
mlp_hparams = {'num_outputs':1, 'num_hiddens_1':10, 'num_hiddens_2':10,
           'dropout_1':0.1, 'dropout_2':0.1, 'lr':0.1}

# %%
mlp_model = DropoutMLPRegressor(**mlp_hparams)

# %%
mdls = {'lr': lr_model, 'mlp': mlp_model}
# mdls = {'mlp': mlp_model}

for name, mdl in mdls.items():
    trainer = Trainer(max_epochs=100)
    models, avg_val_log_loss = k_fold(trainer, data, k=5, model=mdl)
    print(f'{name}: average validation log mse = {avg_val_log_loss}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       4 for name, mdl in mdls.items():
#       5     trainer = Trainer(max_epochs=100)
# ----> 6     models, avg_val_log_loss = k_fold(trainer, data, k=5, model=mdl)
#       7     print(f'{name}: average validation log mse = {avg_val_log_loss}')
#
# Input In [15], in k_fold(trainer, data, k, model)
#       4 model.board.yscale='log'
#       5 if i != 0: model.board.display = False
# ----> 6 trainer.fit(model, data_fold)
#       7 val_loss.append(float(model.board.data['val_loss'][-1].y))
#       8 models.append(model)
#
# File ~/Documents/Documents/Learning/d2l-en/d2l-en/d2l_pytorch/mylearnings/myd2l/notebooks/refactored/../../omd2l/models/base/Trainer.py:94, in Trainer.fit(self, model, data)
#      92 self.val_batch_idx = 0
#      93 for self.epoch in range(self.max_epochs):
# ---> 94     self.fit_epoch()
#
# File ~/Documents/Documents/Learning/d2l-en/d2l-en/d2l_pytorch/mylearnings/myd2l/notebooks/refactored/../../omd2l/models/base/Trainer.py:113, in Trainer.fit_epoch(self)
#     111 for batch in self.val_dataloader:
#     112     with torch.no_grad():
# --> 113         self.model.validation_step(self.prepare_batch(batch))
#     114     self.val_batch_idx += 1
#
# File ~/Documents/Documents/Learning/d2l-en/d2l-en/d2l_pytorch/mylearnings/myd2l/notebooks/refactored/../../omd2l/models/base/Module.py:93, in Module.validation_step(self, batch)
#      91 def validation_step(self, batch):
#      92     l = self.loss(self(*batch[:-1]), batch[-1])
# ---> 93     self.plot('loss', l, train=False)
#
# File ~/Documents/Documents/Learning/d2l-en/d2l-en/d2l_pytorch/mylearnings/myd2l/notebooks/refactored/../../omd2l/models/base/Module.py:83, in Module.plot(self, key, value, train)
#      80     x = self.trainer.epoch + 1
#      81     n = self.trainer.num_val_batches / \
#      82         self.plot_valid_per_epoch
# ---> 83 self.board.draw(x, compute.numpy(compute.to(value, compute.cpu())),
#      84                 ('train_' if train else 'val_') + key,
#      85                 every_n=int(n))
#
# File ~/Documents/Documents/Learning/d2l-en/d2l-en/d2l_pytorch/mylearnings/myd2l/notebooks/refactored/../../omd2l/models/base/ProgressBoard.py:101, in ProgressBoard.draw(self, x, y, label, every_n)
#      99 axes.set_yscale(self.yscale)
#     100 axes.legend(plt_lines, labels)
# --> 101 display.display(self.fig)
#     102 display.clear_output(wait=True)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py:1333, in FigureCanvasSVG.print_svg(self, filename, dpi, bbox_inches_restore, metadata, *args)
#    1328 w, h = width * 72, height * 72
#    1329 renderer = MixedModeRenderer(
#    1330     self.figure, width, height, dpi,
#    1331     RendererSVG(w, h, fh, image_dpi=dpi, metadata=metadata),
#    1332     bbox_inches_restore=bbox_inches_restore)
# -> 1333 self.figure.draw(renderer)
#    1334 renderer.finalize()
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/lines.py:776, in Line2D.draw(self, renderer)
#     773             gc.set_sketch_params(*self.get_sketch_params())
#     775         gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 776         renderer.draw_path(gc, tpath, affine.frozen())
#     777         gc.restore()
#     779 if self._marker and self._markersize > 0:
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py:658, in RendererSVG.draw_path(self, gc, path, transform, rgbFace)
#     656 def draw_path(self, gc, path, transform, rgbFace=None):
#     657     # docstring inherited
# --> 658     trans_and_flip = self._make_flip_transform(transform)
#     659     clip = (rgbFace is None and gc.get_hatch_path() is None)
#     660     simplify = path.should_simplify and clip
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py:462, in RendererSVG._make_flip_transform(self, transform)
#     460 def _make_flip_transform(self, transform):
#     461     return (transform +
# --> 462             Affine2D()
#     463             .scale(1.0, -1.0)
#     464             .translate(0.0, self.height))
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/transforms.py:2077, in Affine2D.scale(self, sx, sy)
#    2075 self._mtx[1, 1] *= sy
#    2076 self._mtx[1, 2] *= sy
# -> 2077 self.invalidate()
#    2078 return self
#
# File ~/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/matplotlib/transforms.py:175, in TransformNode.invalidate(self)
#     170 def invalidate(self):
#     171     """
#     172     Invalidate this `TransformNode` and triggers an invalidation of its
#     173     ancestors.  Should be called any time the transform changes.
#     174     """
# --> 175     value = self.INVALID
#     176     if self.is_affine:
#     177         value = self.INVALID_AFFINE
#
# KeyboardInterrupt:
