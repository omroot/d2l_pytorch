# %%
# %matplotlib inline
import math
import time
import numpy as np

import torch

# %%
import sys

# %%
sys.path.append('../../')

# %%
from omd2l.data.DataModule import SyntheticRegressionData, FashionMNIST

# %%
from omd2l.models.base.Trainer import Trainer

# %%
from omd2l.models.linear.LinearRegressionScratch import LinearRegressionScratch

# %%
from omd2l.models.MLP.MLPScratch import MLPScratch
from omd2l.models.MLP.MLP import MLP
 
from omd2l.models.MLP.DropoutMLPScratch import DropoutMLPScratch
from omd2l.models.MLP.DropoutMLP import DropoutMLP

# %% [markdown]
# # MLP

# %% [markdown]
# ## MLP from scratch

# %%
model = MLPScratch(num_inputs=784, num_outputs=10, num_hiddens=256, lr=0.1)

# %%
data = FashionMNIST(batch_size=256)
trainer = Trainer(max_epochs=10)
trainer.fit(model, data)

# %% [markdown]
# ## Concise implementation

# %%
model = MLP(num_outputs=10, num_hiddens=256, lr=0.1)
trainer.fit(model, data)

# %% [markdown]
# # Dropout MLP

# %% [markdown]
# ## Dropout MLP from scratch

# %%
hparams = {'num_outputs':10, 'num_hiddens_1':256, 'num_hiddens_2':256,
           'dropout_1':0.5, 'dropout_2':0.5, 'lr':0.1}
model = DropoutMLPScratch(**hparams)
data = FashionMNIST(batch_size=256)
trainer = Trainer(max_epochs=10)
trainer.fit(model, data)

# %% [markdown]
# ## Dropout MLP

# %%
model = DropoutMLP(**hparams)
trainer.fit(model, data)
