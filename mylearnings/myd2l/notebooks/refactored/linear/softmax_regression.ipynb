# %%
# %matplotlib inline
import math
import time
import numpy as np
from sklearn.linear_model import LogisticRegression
import  statsmodels.api as sm 
import torch

# %%
import sys 
sys.path.append('../../../')

# %%
from omd2l.data.FashionMNIST import FashionMNIST

# %%
from omd2l.models.base import Trainer

# %%
from omd2l.models.linear import SoftmaxRegressionScratch
from omd2l.models.linear import SoftmaxRegression, SoftmaxRegressionTabular

# %%
data = FashionMNIST(batch_size=256)
# Out:
# ...
# 100%|█████████████████████████| 26421880/26421880 [00:01<00:00, 15772656.43it/s]
# Extracting ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100%|█████████████████████████████████| 29515/29515 [00:00<00:00, 237344.55it/s]
# Extracting ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100%|████████████████████████████| 4422102/4422102 [00:00<00:00, 4671001.33it/s]
# Extracting ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# ...
# 100%|██████████████████████████████████| 5148/5148 [00:00<00:00, 8222496.95it/s]
# Extracting ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw

# %%
data.train.train_data.shape
# Out:
# /Users/oualid/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# torch.Size([60000, 28, 28])

# %%
data.val.test_data.shape
# Out:
# /Users/oualid/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# torch.Size([10000, 28, 28])

# %%
model = SoftmaxRegressionScratch(num_inputs=784, num_outputs=10, lr=0.1)
trainer = Trainer(max_epochs=10)
trainer.fit(model, data)

# %%
model = SoftmaxRegression(num_outputs=10, lr=0.1)
trainer = Trainer(max_epochs=10)
trainer.fit(model, data)

# %%
model = SoftmaxRegression(num_outputs=10, lr=0.1)
trainer = Trainer(max_epochs=100)
trainer.fit(model, data)
